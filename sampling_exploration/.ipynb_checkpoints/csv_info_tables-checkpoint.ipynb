# %% [markdown]
# # Goal of These Studies
# The goal of this study was to detect the asymptomatic incubation period, which is the period during which we want to reduce viral transmission, and the intent of using a machine learning algorithm was to do so only using ECG physiological and electrophysiological data. This model was, in the vast majority of the cases, able to detect the asymptomatic state well before the onset of symptoms, like a fever.

# %%
import pandas as pd
import numpy as np
import os

def find_csv_filenames(path_to_dir, suffix=".csv"):
    filenames = os.listdir(path_to_dir)
    return [filename for filename in filenames if filename.endswith(suffix)]

tables = find_csv_filenames('/Users/camilledunning/Desktop/MachineLearningPython/scripps-data')
tables = [c for c in tables if c != 'SubjectMetaData.csv-Table 1.csv']
tables
# Out:
# ['MARV-Cyno-IM.csv-Table 1.csv',
#  'EBOV-Cyno-Aero-1.csv-Table 1.csv',
#  'MARV-Rhesus-Aero.csv-Table 1.csv',
#  'NIPAH-AGM-IT.csv-Table 1.csv',
#  'LASSA-Cyno-Aero.csv-Table 1.csv',
#  'EBOV-Cyno-Aero-2.csv-Table 1.csv',
#  'Plague-AGM-Aero.csv-Table 1.csv']

# %% [markdown]
# # Marburg Virus - Cynomolgus Macaques
# * 9 subjects
# * For subject with the most data, 4 days before exposure, 10 days after exposure

# %%
mar1 = pd.read_csv(tables[0])
[sub + str(mar1[mar1['SubjectName'] == sub].shape) for sub in np.unique(mar1['SubjectName'])]
print(max(mar1[(mar1['SubjectName'] == 'mci003') & (mar1['Y'] == 0)]['Day']) + 1)
print(max(mar1[(mar1['SubjectName'] == 'mci003') & (mar1['Y'] == 1)]['Day']) + 1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-53c3f46de220> in <module>
# ----> 1 mar1 = pd.read_csv(tables[0])
#       2 [sub + str(mar1[mar1['SubjectName'] == sub].shape) for sub in np.unique(mar1['SubjectName'])]
#       3 print(max(mar1[(mar1['SubjectName'] == 'mci003') & (mar1['Y'] == 0)]['Day']) + 1)
#       4 print(max(mar1[(mar1['SubjectName'] == 'mci003') & (mar1['Y'] == 1)]['Day']) + 1)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'MARV-Cyno-IM.csv-Table 1.csv' does not exist: b'MARV-Cyno-IM.csv-Table 1.csv'

# %% [markdown]
# ## Some Data Type Meanings
# * **AOPSystolic** - Aortic pressure, blood pressure at root of aorta, systolic: force of blood against artery walls while ventricles squeeze
# * **AOPDiastolic** - Force of blood against artery walls as ventricles in heart relax
# * **Resp** - Respiration rate
# * **Temp** - Temperature measurement
# * **PR** - PR interval on ECG, beginning of P wave (wave generated by depolarization front as it transits the atria)
# * **QT** - Time from start of the Q wave to the end of the T wave
# * **LVPSystolic/Diastolic** - Left ventricular pressure
# * **Bazett** - Bazett formula, corrects measured QT interval to a value attributable to a heart rate of 60 BPM
# * **Fridericia** - Fridericia formula, maybe more accurate than the Bazett formula, as that formula has been said to overcorrect at fast heart rates and undercorrect at slow heart rates

# %%
def gen_table(table):
    df = pd.read_csv(table)
    cols = df.columns[5:]
    _, idx = np.unique([col.split('_')[0] for col in cols], return_index=True)
    cols = cols[np.sort(idx)]
    tbl = pd.DataFrame(cols).set_index([0])
    tbl.index.rename('Data Types', inplace=True)
    tbl['Sampling Frequency'] = list(range(0, len(tbl)))

    s_freqs = []

    for sub in np.unique(df['SubjectName']):
        for y in np.unique(df['Y']):
            for d in np.unique(df[df['SubjectName'] == sub]['Day']):
                s_freqs.append(len(df[(df['SubjectName'] == sub) & (df['Y'] == y) & (df['Day'] == d)]))

    s_freqs = [f for f in s_freqs if f != 0]
    s_freqs

    median_s_freq = round(np.median(s_freqs), 0)
    tbl['Sampling Frequency'] = np.repeat(median_s_freq, len(tbl))

    num_missing_data = abs(sum(s_freqs - median_s_freq))
    percent_missing_data = round(num_missing_data / len(df), 3)
    tbl['Percent Data Missing'] = np.repeat(percent_missing_data, len(tbl))

    if all(df):
        tbl['# of Subjects Represented'] = np.repeat(len(np.unique(df['SubjectName'])), len(tbl))

    tbl['Median'] = [np.median(df[col]) for col in cols]
    tbl['Q25'] = [df[col].quantile(0.25) for col in cols]
    tbl['Q75'] = [df[col].quantile(0.75) for col in cols]
    tbl['Min'] = [min(df[col]) for col in cols]
    tbl['Max'] = [max(df[col]) for col in cols]
    return tbl
    
gen_table(tables[0])
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-5-335b4f6409c0> in <module>
#      32     return tbl
#      33
# ---> 34 gen_table(tables[0])
#
# <ipython-input-5-335b4f6409c0> in gen_table(table)
#       1 def gen_table(table):
# ----> 2     cols = cols[np.sort(idx)]
#       3     tbl = pd.DataFrame(cols).set_index([0])
#       4     tbl.index.rename('Data Types', inplace=True)
#       5     tbl['Sampling Frequency'] = list(range(0, len(tbl)))
#
# UnboundLocalError: local variable 'cols' referenced before assignment

# %% [markdown]
# # Ebola - Cynomolgus Macaques #1

# %%
ebo1 = pd.read_csv(tables[1])
print(len(np.unique(ebo1['SubjectName'])))
print([sub + str(ebo1[ebo1['SubjectName'] == sub].shape) for sub in np.unique(ebo1['SubjectName'])])
print(max(ebo1[(ebo1['SubjectName'] == 'e1009') & (ebo1['Y'] == 0)]['Day']) + 1)
print(max(ebo1[(ebo1['SubjectName'] == 'e1009') & (ebo1['Y'] == 1)]['Day']) + 1)
# Out:
# 6
# ['e1001(604, 45)', 'e1004(632, 45)', 'e1005(650, 45)', 'e1009(669, 45)', 'e1011(574, 45)', 'e1015(641, 45)']
# 8
# 8

# %% [markdown]
# * 6 subjects
# * For subject with the most data, 8 days before exposure, 8 days after exposure

# %%
gen_table(tables[1])
# Out:
#                    Sampling Frequency  Percent Data Missing  \
# Data Types
# AOPAMean_Mean                    48.0                 0.082
# AOPDiastolic_Mean                48.0                 0.082
# AOPSystolic_Mean                 48.0                 0.082
# Activity_Mean                    48.0                 0.082
# Bazett_Mean                      48.0                 0.082
# Fridericia_Mean                  48.0                 0.082
# HR_Mean                          48.0                 0.082
# PR_Mean                          48.0                 0.082
# QRS_Mean                         48.0                 0.082
# QT_Mean                          48.0                 0.082
# RR_Mean                          48.0                 0.082
# RespMean_Mean                    48.0                 0.082
# Temp_Mean                        48.0                 0.082
# Y                                48.0                 0.082
#
#                    # of Subjects Represented    Median       Q25       Q75  \
# Data Types
# AOPAMean_Mean                              6 -0.044589 -0.601681  0.566622
# AOPDiastolic_Mean                          6 -0.046605 -0.573127  0.537039
# AOPSystolic_Mean                           6 -0.040211 -0.616388  0.583080
# Activity_Mean                              6  0.000494 -0.053321  0.016397
# Bazett_Mean                                6 -0.029136 -0.365756  0.255027
# Fridericia_Mean                            6 -0.156367 -0.731050  0.293546
# HR_Mean                                    6  0.176912 -0.302573  0.919383
# PR_Mean                                    6 -0.047928 -0.444173  0.282391
# QRS_Mean                                   6 -0.075048 -0.446663  0.231754
# QT_Mean                                    6 -0.277198 -1.061480  0.334909
# RR_Mean                                    6 -0.224519 -0.878002  0.273697
# RespMean_Mean                              6  0.086072 -0.338884  0.678047
# Temp_Mean                                  6  0.375075 -0.483354  1.545303
# Y                                          6  0.000000  0.000000  1.000000
#
#                          Min        Max
# Data Types
# AOPAMean_Mean     -12.982389   9.683679
# AOPDiastolic_Mean -12.121885   9.311269
# AOPSystolic_Mean  -13.789496  10.027460
# Activity_Mean      -1.510156   2.104627
# Bazett_Mean        -4.087383   6.306805
# Fridericia_Mean    -6.192722   4.894960
# HR_Mean            -2.790744  24.262667
# PR_Mean            -8.592986   6.672442
# QRS_Mean           -7.093461   4.266291
# QT_Mean           -10.987020   4.991559
# RR_Mean            -7.560166   4.837696
# RespMean_Mean      -2.285119  16.345105
# Temp_Mean         -22.290715  39.858497
# Y                   0.000000   1.000000

# %% [markdown]
# # Marburg Virus - Rhesus Macaques

# %%
mar2 = pd.read_csv(tables[2])
print(len(np.unique(mar2['SubjectName'])))
print([sub + str(mar2[mar2['SubjectName'] == sub].shape) for sub in np.unique(mar2['SubjectName'])])
print(max(mar2[(mar2['SubjectName'] == 'mra002') & (mar2['Y'] == 0)]['Day']) + 1)
print(max(mar2[(mar2['SubjectName'] == 'mra002') & (mar2['Y'] == 1)]['Day']) + 1)
# Out:
# 5
# ['mra001(704, 63)', 'mra002(705, 63)', 'mra003(685, 63)', 'mra004(688, 63)', 'mra005(666, 63)']
# 7
# 8

# %% [markdown]
# * 5 subjects
# * For subject with the most data, 7 days before exposure, 8 days after exposure

# %%
gen_table(tables[2])
# Out:
#                    Sampling Frequency  Percent Data Missing  \
# Data Types
# AOPSystolic_Mean                 48.0                 0.044
# AOPDiastolic_Mean                48.0                 0.044
# RespMean_Mean                    48.0                 0.044
# Temp_Mean                        48.0                 0.044
# QT_Mean                          48.0                 0.044
# PR_Mean                          48.0                 0.044
# QRS_Mean                         48.0                 0.044
# RR_Mean                          48.0                 0.044
# HR_Mean                          48.0                 0.044
# LVPSystolic_Mean                 48.0                 0.044
# LVPDiastolic_Mean                48.0                 0.044
# LVPRate_Mean                     48.0                 0.044
# Bazett_Mean                      48.0                 0.044
# Fridericia_Mean                  48.0                 0.044
# AOPAMean_Mean                    48.0                 0.044
# LVPMean_Mean                     48.0                 0.044
# ITPDepth_Mean                    48.0                 0.044
# APP_Mean                         48.0                 0.044
# ANP_Mean                         48.0                 0.044
# Y                                48.0                 0.044
#
#                    # of Subjects Represented    Median       Q25       Q75  \
# Data Types
# AOPSystolic_Mean                           5 -0.101547 -0.629598  0.634120
# AOPDiastolic_Mean                          5 -0.193828 -0.779765  0.399196
# RespMean_Mean                              5  0.170465 -0.463914  0.865989
# Temp_Mean                                  5  0.426143 -0.334512  2.435568
# QT_Mean                                    5 -0.049829 -0.815337  0.648257
# PR_Mean                                    5  0.070935 -0.373140  0.579794
# QRS_Mean                                   5  0.076545 -0.316640  0.537907
# RR_Mean                                    5  0.200541 -0.406009  0.846467
# HR_Mean                                    5 -0.242146 -0.774730  0.377216
# LVPSystolic_Mean                           5 -0.197010 -0.627188  0.355767
# LVPDiastolic_Mean                          5  0.102880 -0.280690  0.354991
# LVPRate_Mean                               5 -0.225136 -0.726936  0.360045
# Bazett_Mean                                5 -0.250210 -0.904457  0.281315
# Fridericia_Mean                            5 -0.205436 -0.936022  0.436963
# AOPAMean_Mean                              5 -0.158434 -0.737338  0.487637
# LVPMean_Mean                               5 -0.326387 -0.818129  0.163549
# ITPDepth_Mean                              5 -0.090334 -0.438388  0.276156
# APP_Mean                                   5 -0.032810 -0.347583  0.320134
# ANP_Mean                                   5 -0.173995 -0.520856  0.161403
# Y                                          5  1.000000  0.000000  1.000000
#
#                          Min        Max
# Data Types
# AOPSystolic_Mean  -10.357273   8.875209
# AOPDiastolic_Mean -10.939830   4.792388
# RespMean_Mean      -4.857199   7.398475
# Temp_Mean         -11.196541  32.095655
# QT_Mean            -8.536640   6.002094
# PR_Mean            -7.064624   6.442386
# QRS_Mean           -9.318058   6.822095
# RR_Mean            -4.552082   5.568404
# HR_Mean            -3.415402   7.918673
# LVPSystolic_Mean  -10.608516  13.199828
# LVPDiastolic_Mean -91.054761   3.088446
# LVPRate_Mean       -3.196202   7.864124
# Bazett_Mean        -6.599259   7.201817
# Fridericia_Mean    -9.098912   7.594874
# AOPAMean_Mean     -11.823724   6.342704
# LVPMean_Mean       -5.166659   4.650198
# ITPDepth_Mean      -2.757225   7.755238
# APP_Mean           -2.578690   8.861428
# ANP_Mean           -2.764607   8.499110
# Y                   0.000000   1.000000

# %% [markdown]
# # NIPAH Virus - African Green Monkey

# %%
ni1 = pd.read_csv(tables[3])
print(len(np.unique(ni1['SubjectName'])))
print([sub + str(ni1[ni1['SubjectName'] == sub].shape) for sub in np.unique(ni1['SubjectName'])])
print(max(ni1[(ni1['SubjectName'] == 'n1001') & (ni1['Y'] == 0)]['Day']) + 1)
print(max(ni1[(ni1['SubjectName'] == 'n1001') & (ni1['Y'] == 1)]['Day']) + 1)
# Out:
# 7
# ['n1001(1199, 51)', 'n1002(633, 51)', 'n1003(713, 51)', 'n1004(1199, 51)', 'n2001(746, 51)', 'n2002(378, 51)', 'n2003(363, 51)']
# 6
# 21

# %% [markdown]
# * 7 subjects
# * For subject with the most data, 6 days before exposure, 21 days after exposure

# %%
gen_table(tables[3])
# Out:
#                    Sampling Frequency  Percent Data Missing  \
# Data Types
# AOPAMean_Mean                    48.0                 0.092
# AOPDiastolic_Mean                48.0                 0.092
# AOPSystolic_Mean                 48.0                 0.092
# Bazett_Mean                      48.0                 0.092
# Fridericia_Mean                  48.0                 0.092
# HR_Mean                          48.0                 0.092
# LVPDiastolic_Mean                48.0                 0.092
# LVPMean_Mean                     48.0                 0.092
# LVPRate_Mean                     48.0                 0.092
# LVPSystolic_Mean                 48.0                 0.092
# PR_Mean                          48.0                 0.092
# QRS_Mean                         48.0                 0.092
# QT_Mean                          48.0                 0.092
# RR_Mean                          48.0                 0.092
# Temp_Mean                        48.0                 0.092
# Y                                48.0                 0.092
#
#                    # of Subjects Represented    Median       Q25       Q75  \
# Data Types
# AOPAMean_Mean                              7 -0.129179 -0.782278  0.668341
# AOPDiastolic_Mean                          7 -0.086859 -0.758263  0.689559
# AOPSystolic_Mean                           7 -0.138715 -0.839969  0.586775
# Bazett_Mean                                7  0.218998 -0.274254  0.905813
# Fridericia_Mean                            7  0.042155 -0.555611  0.662946
# HR_Mean                                    7  0.358441 -0.326017  1.623131
# LVPDiastolic_Mean                          7 -0.293824 -1.231214  0.173113
# LVPMean_Mean                               7 -0.211752 -0.771987  0.388339
# LVPRate_Mean                               7  0.346307 -0.321497  1.561563
# LVPSystolic_Mean                           7 -0.158142 -0.669260  0.515249
# PR_Mean                                    7 -0.063700 -0.839334  0.602112
# QRS_Mean                                   7 -0.027242 -0.588048  0.427082
# QT_Mean                                    7 -0.387751 -1.437088  0.485982
# RR_Mean                                    7 -0.445573 -1.471768  0.291604
# Temp_Mean                                  7  0.720315 -0.377588  2.264065
# Y                                          7  1.000000  0.000000  1.000000
#
#                           Min        Max
# Data Types
# AOPAMean_Mean      -10.125261  11.523314
# AOPDiastolic_Mean   -8.435507   9.164154
# AOPSystolic_Mean   -11.386101  12.337743
# Bazett_Mean         -3.125161   8.643236
# Fridericia_Mean     -7.220124   8.555924
# HR_Mean             -2.086436  14.786177
# LVPDiastolic_Mean -137.094208   6.569729
# LVPMean_Mean        -4.022255   8.596418
# LVPRate_Mean        -1.851359  99.298887
# LVPSystolic_Mean    -5.571174  11.963397
# PR_Mean             -6.144112   5.488863
# QRS_Mean           -11.900585   3.814244
# QT_Mean            -10.667755   4.973849
# RR_Mean             -6.598448   3.499658
# Temp_Mean          -30.909385  41.333055
# Y                    0.000000   1.000000

# %% [markdown]
# # Lassa Virus

# %%
la = pd.read_csv(tables[4])
print(len(np.unique(la['SubjectName'])))
print([sub + str(la[la['SubjectName'] == sub].shape) for sub in np.unique(la['SubjectName'])])
print(max(la[(la['SubjectName'] == 'l004') & (la['Y'] == 0)]['Day']) + 1)
print(max(la[(la['SubjectName'] == 'l004') & (la['Y'] == 1)]['Day']) + 1)
# Out:
# 4
# ['l001(765, 63)', 'l002(868, 63)', 'l003(763, 63)', 'l004(2252, 63)']
# 7
# 41

# %% [markdown]
# * 4 subjects
# * For subject with the most data, 7 days before exposure, 41 days after exposure

# %%
gen_table(tables[4])
# Out:
#                    Sampling Frequency  Percent Data Missing  \
# Data Types
# AOPSystolic_Mean                 48.0                 0.053
# AOPDiastolic_Mean                48.0                 0.053
# RespMean_Mean                    48.0                 0.053
# Temp_Mean                        48.0                 0.053
# QT_Mean                          48.0                 0.053
# PR_Mean                          48.0                 0.053
# QRS_Mean                         48.0                 0.053
# RR_Mean                          48.0                 0.053
# HR_Mean                          48.0                 0.053
# LVPSystolic_Mean                 48.0                 0.053
# LVPDiastolic_Mean                48.0                 0.053
# LVPRate_Mean                     48.0                 0.053
# Bazett_Mean                      48.0                 0.053
# Fridericia_Mean                  48.0                 0.053
# AOPAMean_Mean                    48.0                 0.053
# LVPMean_Mean                     48.0                 0.053
# ITPDepth_Mean                    48.0                 0.053
# APP_Mean                         48.0                 0.053
# ANP_Mean                         48.0                 0.053
# Y                                48.0                 0.053
#
#                    # of Subjects Represented    Median       Q25       Q75  \
# Data Types
# AOPSystolic_Mean                           4 -0.602288 -1.360249 -0.015445
# AOPDiastolic_Mean                          4 -0.299385 -0.850813  0.260644
# RespMean_Mean                              4  0.235189 -0.452365  1.302369
# Temp_Mean                                  4  1.086217 -0.227678  4.051556
# QT_Mean                                    4 -0.427122 -1.520196  0.539966
# PR_Mean                                    4 -0.482029 -1.494143  0.211980
# QRS_Mean                                   4 -0.048603 -0.597972  0.431852
# RR_Mean                                    4 -0.557252 -1.460536  0.205992
# HR_Mean                                    4  0.510774 -0.288236  1.805464
# LVPSystolic_Mean                           4 -0.516158 -1.038237 -0.154436
# LVPDiastolic_Mean                          4  0.329983  0.086645  0.896479
# LVPRate_Mean                               4  0.360018 -0.272022  1.476991
# Bazett_Mean                                4  0.483997 -0.173714  1.303026
# Fridericia_Mean                            4  0.057071 -0.764450  0.934759
# AOPAMean_Mean                              4 -0.504603 -1.194420  0.105515
# LVPMean_Mean                               4 -0.024801 -0.554211  0.616433
# ITPDepth_Mean                              4 -0.113301 -0.526465  0.376682
# APP_Mean                                   4 -0.085947 -0.520109  0.359740
# ANP_Mean                                   4 -0.107035 -0.529368  0.349733
# Y                                          4  1.000000  1.000000  1.000000
#
#                          Min        Max
# Data Types
# AOPSystolic_Mean   -5.395446   4.789397
# AOPDiastolic_Mean  -4.077971   2.847689
# RespMean_Mean      -3.641613  21.841540
# Temp_Mean         -17.613714  28.416362
# QT_Mean            -8.987419   7.288494
# PR_Mean            -5.344537   4.722723
# QRS_Mean           -4.672350   3.382814
# RR_Mean            -5.148415   5.108762
# HR_Mean            -3.037293   9.949064
# LVPSystolic_Mean   -4.688526   5.629364
# LVPDiastolic_Mean -32.924556   5.690661
# LVPRate_Mean       -2.468469   9.747415
# Bazett_Mean        -3.902030   8.329769
# Fridericia_Mean    -4.609095   6.282945
# AOPAMean_Mean      -6.443471   3.352195
# LVPMean_Mean       -2.563368   3.963082
# ITPDepth_Mean      -3.103233  15.062342
# APP_Mean           -3.264506   9.209851
# ANP_Mean           -3.267413  10.341603
# Y                   0.000000   1.000000

# %% [markdown]
# # Ebola - Cynomolgus Macaques #2

# %%
ebo2 = pd.read_csv(tables[5])
print(len(np.unique(ebo2['SubjectName'])))
print([sub + str(ebo2[ebo2['SubjectName'] == sub].shape) for sub in np.unique(ebo2['SubjectName'])])
print(max(ebo2[(ebo2['SubjectName'] == 'e2003') & (ebo2['Y'] == 0)]['Day']) + 1)
print(max(ebo2[(ebo2['SubjectName'] == 'e2003') & (ebo2['Y'] == 1)]['Day']) + 1)
# Out:
# 8
# ['e2002(637, 45)', 'e2003(697, 45)', 'e2006(614, 45)', 'e2007(658, 45)', 'e2010(428, 45)', 'e2012(362, 45)', 'e2013(576, 45)', 'e2014(632, 45)']
# 7
# 8

# %% [markdown]
# * 8 subjects
# * For subject with the most data, 7 days before exposure, 8 days after exposure

# %%
gen_table(tables[5])
# Out:
#                    Sampling Frequency  Percent Data Missing  \
# Data Types
# AOPAMean_Mean                    46.0                 0.159
# AOPDiastolic_Mean                46.0                 0.159
# AOPSystolic_Mean                 46.0                 0.159
# Activity_Mean                    46.0                 0.159
# Bazett_Mean                      46.0                 0.159
# Fridericia_Mean                  46.0                 0.159
# HR_Mean                          46.0                 0.159
# PR_Mean                          46.0                 0.159
# QRS_Mean                         46.0                 0.159
# QT_Mean                          46.0                 0.159
# RR_Mean                          46.0                 0.159
# RespMean_Mean                    46.0                 0.159
# Temp_Mean                        46.0                 0.159
# Y                                46.0                 0.159
#
#                    # of Subjects Represented    Median       Q25       Q75  \
# Data Types
# AOPAMean_Mean                              8 -0.003708 -0.514571  0.615087
# AOPDiastolic_Mean                          8  0.021720 -0.460259  0.584153
# AOPSystolic_Mean                           8 -0.037733 -0.554137  0.566964
# Activity_Mean                              8  0.000847 -0.029624  0.018525
# Bazett_Mean                                8 -0.109110 -0.538512  0.203893
# Fridericia_Mean                            8 -0.274003 -1.110030  0.207119
# HR_Mean                                    8  0.266070 -0.276571  1.239282
# PR_Mean                                    8 -0.095962 -0.591451  0.299793
# QRS_Mean                                   8 -0.025106 -0.326806  0.269726
# QT_Mean                                    8 -0.450953 -1.690132  0.270463
# RR_Mean                                    8 -0.297724 -1.073385  0.235616
# RespMean_Mean                              8  0.142541 -0.290105  0.729439
# Temp_Mean                                  8  0.309394 -0.515832  1.452930
# Y                                          8  1.000000  0.000000  1.000000
#
#                          Min        Max
# Data Types
# AOPAMean_Mean     -32.705997  22.009888
# AOPDiastolic_Mean -32.446644  22.135060
# AOPSystolic_Mean  -31.606238  20.505507
# Activity_Mean      -0.923573   5.621855
# Bazett_Mean       -11.904234  28.178474
# Fridericia_Mean   -14.669014  19.217052
# HR_Mean            -4.171943  80.900777
# PR_Mean           -17.577943  14.346717
# QRS_Mean           -5.101806   5.549823
# QT_Mean           -43.173638  10.317883
# RR_Mean           -26.393974   5.379538
# RespMean_Mean      -4.291731  17.109422
# Temp_Mean         -53.123151  36.154280
# Y                   0.000000   1.000000

# %% [markdown]
# # Plague

# %%
pl = pd.read_csv(tables[6])
print(len(np.unique(pl['SubjectName'])))
print([sub + str(pl[pl['SubjectName'] == sub].shape) for sub in np.unique(pl['SubjectName'])])
print(max(pl[(pl['SubjectName'] == 'p002') & (pl['Y'] == 0)]['Day']) + 1)
print(max(pl[(pl['SubjectName'] == 'p002') & (pl['Y'] == 1)]['Day']) + 1)
# Out:
# 4
# ['p001(422, 63)', 'p002(542, 63)', 'p003(472, 63)', 'p004(537, 63)']
# 7
# 6

# %% [markdown]
# * 4 subjects
# * For subject with the most data, 7 days before exposure, 6 days after exposure

# %%
gen_table(tables[6])
# Out:
#                    Sampling Frequency  Percent Data Missing  \
# Data Types
# AOPSystolic_Mean                 47.0                  0.12
# AOPDiastolic_Mean                47.0                  0.12
# RespMean_Mean                    47.0                  0.12
# Temp_Mean                        47.0                  0.12
# QT_Mean                          47.0                  0.12
# PR_Mean                          47.0                  0.12
# QRS_Mean                         47.0                  0.12
# RR_Mean                          47.0                  0.12
# HR_Mean                          47.0                  0.12
# LVPSystolic_Mean                 47.0                  0.12
# LVPDiastolic_Mean                47.0                  0.12
# LVPRate_Mean                     47.0                  0.12
# Bazett_Mean                      47.0                  0.12
# Fridericia_Mean                  47.0                  0.12
# AOPAMean_Mean                    47.0                  0.12
# LVPMean_Mean                     47.0                  0.12
# ITPDepth_Mean                    47.0                  0.12
# APP_Mean                         47.0                  0.12
# ANP_Mean                         47.0                  0.12
# Y                                47.0                  0.12
#
#                    # of Subjects Represented    Median       Q25       Q75  \
# Data Types
# AOPSystolic_Mean                           4  0.110942 -0.425753  0.796712
# AOPDiastolic_Mean                          4  0.234994 -0.342205  0.637629
# RespMean_Mean                              4 -0.028040 -0.282588  0.309316
# Temp_Mean                                  4  0.151729 -0.594166  1.100494
# QT_Mean                                    4 -0.150204 -1.078289  0.401825
# PR_Mean                                    4 -0.181150 -0.816333  0.262990
# QRS_Mean                                   4  0.009656 -0.390772  0.338498
# RR_Mean                                    4 -0.203803 -0.950242  0.250130
# HR_Mean                                    4  0.149704 -0.248654  0.947132
# LVPSystolic_Mean                           4  0.036734 -0.450513  0.727963
# LVPDiastolic_Mean                          4  0.045465 -1.053653  0.517381
# LVPRate_Mean                               4  0.096108 -0.261880  0.820685
# Bazett_Mean                                4  0.061406 -0.195606  0.391551
# Fridericia_Mean                            4 -0.055054 -0.590591  0.376993
# AOPAMean_Mean                              4  0.215388 -0.356592  0.753876
# LVPMean_Mean                               4  0.095976 -0.521141  0.832079
# ITPDepth_Mean                              4 -0.066088 -0.476159  0.392301
# APP_Mean                                   4 -0.143326 -0.524332  0.250005
# ANP_Mean                                   4 -0.102229 -0.473788  0.311213
# Y                                          4  0.000000  0.000000  1.000000
#
#                          Min        Max
# Data Types
# AOPSystolic_Mean   -2.100714  18.915475
# AOPDiastolic_Mean -19.629225   6.441550
# RespMean_Mean      -6.269505  15.803540
# Temp_Mean         -25.646292  37.774330
# QT_Mean           -11.964768   5.131973
# PR_Mean            -6.226110   4.764792
# QRS_Mean           -4.012442  28.227331
# RR_Mean            -6.241178   2.844594
# HR_Mean            -1.847398  14.367946
# LVPSystolic_Mean  -11.430092  13.977909
# LVPDiastolic_Mean -21.186398   3.389600
# LVPRate_Mean       -1.513196  16.522247
# Bazett_Mean        -6.178906   6.809330
# Fridericia_Mean    -9.737372   5.562216
# AOPAMean_Mean      -7.001721   6.520000
# LVPMean_Mean       -6.166650  13.937400
# ITPDepth_Mean      -2.172711   6.088148
# APP_Mean           -3.853133   8.260329
# ANP_Mean           -3.133002   8.176797
# Y                   0.000000   1.000000
