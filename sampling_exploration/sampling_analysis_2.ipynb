# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %%
csv = '../EBOV-Cyno-Aero-1.csv-Table 1.csv'

# %%
df = pd.read_csv(csv)
df
# Out:
#       Day   Time    TimeS             Study SubjectName  AOPAMean_Mean  \
# 0       0  16:32     1800  EBOV-Cyno-Aero-1       e1001       0.181102
# 1       0  17:02     3600  EBOV-Cyno-Aero-1       e1001       0.248157
# 2       0  17:32     5400  EBOV-Cyno-Aero-1       e1001       0.219259
# 3       0  18:02     7200  EBOV-Cyno-Aero-1       e1001       0.325888
# 4       0  18:32     9000  EBOV-Cyno-Aero-1       e1001       0.735482
# ...   ...    ...      ...               ...         ...            ...
# 3765    6   7:28  1197000  EBOV-Cyno-Aero-1       e1015      -4.988405
# 3766    6   7:58  1198800  EBOV-Cyno-Aero-1       e1015      -5.322331
# 3767    6   8:28  1200600  EBOV-Cyno-Aero-1       e1015      -6.625950
# 3768    6   8:58  1202400  EBOV-Cyno-Aero-1       e1015      -7.449465
# 3769    6   9:28  1204200  EBOV-Cyno-Aero-1       e1015      -7.673655
#
#       AOPAMean_Q25  AOPAMean_Q75  AOPDiastolic_Mean  AOPDiastolic_Q25  ...  \
# ...

# %%
df_table = pd.DataFrame(df.columns).set_index([0])
df_table.index.rename('Column', inplace=True)
df_table
# Out:
# Empty DataFrame
# Columns: []
# Index: [Day, Time, TimeS, Study, SubjectName, AOPAMean_Mean, AOPAMean_Q25, AOPAMean_Q75, AOPDiastolic_Mean, AOPDiastolic_Q25, AOPDiastolic_Q75, AOPSystolic_Mean, AOPSystolic_Q25, AOPSystolic_Q75, Activity_Mean, Activity_Q25, Activity_Q75, Bazett_Mean, Bazett_Q25, Bazett_Q75, Fridericia_Mean, Fridericia_Q25, Fridericia_Q75, HR_Mean, HR_Q25, HR_Q75, PR_Mean, PR_Q25, PR_Q75, QRS_Mean, QRS_Q25, QRS_Q75, QT_Mean, QT_Q25, QT_Q75, RR_Mean, RR_Q25, RR_Q75, RespMean_Mean, RespMean_Q25, RespMean_Q75, Temp_Mean, Temp_Q25, Temp_Q75, Y]
